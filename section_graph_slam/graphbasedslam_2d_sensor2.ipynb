# %%
include("../scripts/kf.jl")
# Out:
# draw (generic function with 8 methods)

# %%
function make_ax()
    fig, ax = subplots()
    ax.set_aspect("equal")
    ax.set_xlim(-5,5)
    ax.set_ylim(-5,5)
    ax.set_xlabel("X", fontsize=20)
    ax.set_ylabel("Y", fontsize=20)
    return ax
end
# Out:
# make_ax (generic function with 1 method)

# %%
function draw_trajectory(xs, ax)
    poses = [xs[s] for s in 1:length(xs)]
    ax.scatter([e[1] for e in poses], [e[2] for e in poses], s=5, marker=".", color="black")
    ax.plot([e[1] for e in poses], [e[2] for e in poses], linewidth=0.5, color="black")
end
# Out:
# draw_trajectory (generic function with 1 method)

# %%
function draw_observations(xs, zlist, ax)
    for s in 1:length(xs)
        if !haskey(zlist, s)
            continue
        end
        for obs in zlist[s]
            x,y,theta = xs[s]
            ell,phi = obs[2][1], obs[2][2]
            mx = x + ell*cos(theta+phi)
            my = y + ell*sin(theta+phi)
            ax.plot([x,mx],[y,my], color="pink", alpha=0.5)
        end
    end
end
# Out:
# draw_observations (generic function with 1 method)

# %%
function read_data()
    f = open("log2_for_book.txt", "r")
    lines = readlines(f)
    hat_xs = Dict()
    zlist = Dict()
    delta = 0.0
    us = Dict()
    for line in lines
        tmp = split(line)
        step = parse(Int, tmp[2]) + 1#for 1-indexed
        if tmp[1] == "x"
            hat_xs[step] = [parse(Float64, tmp[3]), 
                parse(Float64, tmp[4]), parse(Float64, tmp[5])]
        elseif tmp[1] == "z"
            if !haskey(zlist, step)
                zlist[step] = []
            end
            push!(zlist[step], (parse(Int, tmp[3]), [parse(Float64, tmp[4]), 
                parse(Float64, tmp[5])]))
        elseif tmp[1] == "delta"
            delta = parse(Float64, tmp[2])
        elseif tmp[1] == "u"
            us[step] = [parse(Float64, tmp[3]), parse(Float64, tmp[4])]
        end
    end
    return hat_xs, zlist, us, delta
end
# Out:
# read_data (generic function with 1 method)

# %%
mutable struct ObsEdge
    t1
    t2
    x1
    x2
    z1
    z2
    omega_upperleft
    omega_upperright
    omega_bottomleft
    omega_bottomright
    xi_upper
    xi_bottom
end

# %%
function ObsEdge_(t1,t2,z1,z2,xs, sensor_noise_rate=[0.14, 0.05])
    @assert z1[1] == z2[1]
    self = ObsEdge(ntuple(x->nothing, fieldcount(ObsEdge))...)
    self.t1, self.t2 = t1, t2
    self.x1, self.x2 = xs[t1], xs[t2]
    self.z1, self.z2 = z1[2], z2[2]
    
    s1 = sin(self.x1[3] + self.z1[2])
    c1 = cos(self.x1[3] + self.z1[2])
    s2 = sin(self.x2[3] + self.z2[2])
    c2 = cos(self.x2[3] + self.z2[2])
    
    hat_e = self.x2[1:2] - self.x1[1:2] + 
        [self.z2[1]*c2 - self.z1[1]*c1, 
        self.z2[1]*s2 - self.z1[1]*s1]
    
    Q1 = Diagonal([(self.z1[1]*sensor_noise_rate[1])^2,
            sensor_noise_rate[2]^2]
        )
    R1 = -[c1 -self.z1[1]*s1;
                s1 self.z1[1]*c1]
    
    Q2 = Diagonal([(self.z2[1]*sensor_noise_rate[1])^2, 
            sensor_noise_rate[2]^2])
    R2 = [c2 -self.z2[1]*s2;
                s2 self.z2[1]*c2]
    Sigma = R1* Q1 * R1' + R2*Q2*R2'
    Omega = inv(Sigma)
    
    B1 = -[1 0 -self.z1[1]*s1;
               0 1 self.z1[1]*c1]
    B2 = [1 0 -self.z2[1]*s2;
               0 1 self.z2[1]*c2]
    self.omega_upperleft = B1' * Omega * B1
    self.omega_upperright = B1' * Omega * B2
    self.omega_bottomleft = B2' * Omega * B1
    self.omega_bottomright = B2' * Omega * B2
    
    self.xi_upper = -B1' * Omega * hat_e
    self.xi_bottom = -B2' * Omega * hat_e
    return self
end
# Out:
# ObsEdge_ (generic function with 2 methods)

# %%
mutable struct MotionEdge
    t1
    t2
    hat_x1
    hat_x2
    Omega
    omega_upperleft
    omega_upperright
    omega_bottomleft
    omega_bottomright
    xi_upper
    xi_bottom
end

# %%
function MotionEdge_( t1, t2, xs, us, delta, 
        motion_noise_stds=Dict("nn"=>0.19, "no"=>0.001, "on"=>0.13, "oo"=>0.2))
    self = MotionEdge(ntuple(x->nothing, fieldcount(MotionEdge))...)
    self.t1, self.t2 = t1,t2
    self.hat_x1, self.hat_x2 = xs[t1], xs[t2]
    nu,omega = us[t2]
    if abs(omega) < 1e-5
        omega = 1e-5
    end
    M = matM(nu, omega, delta, motion_noise_stds)
    A = matA(nu, omega, delta, self.hat_x1[3])
    F = matF(nu, omega, delta, self.hat_x1[3])
    
    self.Omega = inv(A*M*A' + Matrix{Float64}(I, 3, 3)*0.0001)
    self.omega_upperleft = F' * self.Omega * F
    self.omega_upperright = -F' * self.Omega
    self.omega_bottomleft = -self.Omega * F
    self.omega_bottomright = self.Omega
    
    x2 = state_transition(IdealRobot(), nu, omega, delta, self.hat_x1)
    self.xi_upper = F' * self.Omega * (self.hat_x2 - x2)
    self.xi_bottom = -self.Omega * (self.hat_x2 - x2)
    return self
end
# Out:
# MotionEdge_ (generic function with 2 methods)

# %%
function add_edge(edge, Omega, xi)
    f1, f2 = 1+(edge.t1-1)*3, 1+(edge.t2-1)*3
    t1, t2 = f1 + 2, f2 + 2
    Omega[f1:t1, f1:t1] += edge.omega_upperleft
    Omega[f1:t1, f2:t2] += edge.omega_upperright
    Omega[f2:t2, f1:t1] += edge.omega_bottomleft
    Omega[f2:t2, f2:t2] += edge.omega_bottomright
    xi[f1:t1] += edge.xi_upper
    xi[f2:t2] += edge.xi_bottom
end
# Out:
# add_edge (generic function with 1 method)

# %%
function make_edges(hat_xs, zlist)
    landmark_keys_zlist = Dict()
    for step in keys(zlist)
        for z in zlist[step]
            landmark_id = z[1]
            if !haskey(landmark_keys_zlist,landmark_id)
                landmark_keys_zlist[landmark_id] = []
            end
            push!(landmark_keys_zlist[landmark_id],(step,z))
        end
    end

    edges = []
    for landmark_id in keys(landmark_keys_zlist)
        for i in 1:length(landmark_keys_zlist[landmark_id])
            for j in i+1:length(landmark_keys_zlist[landmark_id])
                xz1 = landmark_keys_zlist[landmark_id][i]
                xz2 = landmark_keys_zlist[landmark_id][j]
                push!(edges, ObsEdge_(xz1[1], xz2[1], xz1[2], xz2[2], hat_xs))
            end
        end
    end
    return edges, landmark_keys_zlist
end
# Out:
# make_edges (generic function with 1 method)

# %%
function draw_edges(edges, ax)
    for e in edges
        ax.plot([e.x1[1], e.x2[1]], [e.x1[2], e.x2[2]], color="red", alpha=0.5)
    end
end
# Out:
# draw_edges (generic function with 1 method)

# %%
function draw(xs, zlist, edges)
    ax = make_ax()
    draw_observations(xs, zlist, ax)
#     draw_edges(edges, ax)
    draw_trajectory(xs, ax)
end
# Out:
# draw (generic function with 9 methods)

# %%
hat_xs, zlist, us, delta = read_data()
dim = length(hat_xs) * 3
glob_edges = []
for n in 1:10000
    edges, _ = make_edges(hat_xs, zlist)
    for i in 1:length(hat_xs)-1
        for _ in 1:100
            push!(edges, MotionEdge_(i, i+1, hat_xs, us, delta))
        end
    end
    Omega = zeros(dim, dim)
    xi = zeros(dim)
    Omega[1:3, 1:3] += Matrix{Float64}(I, 3, 3) * 1000000
    
    for e in edges
        add_edge(e, Omega, xi)
    end
    
    delta_xs = inv(Omega) * xi
    
    for i in 1:length(hat_xs)
        hat_xs[i] += delta_xs[1+3*(i-1) : i*3]
    end
    
    diff = norm(delta_xs)
    println(@sprintf("%d回目の繰り返し: %f", n, diff))
    if diff < 0.01
        draw(hat_xs, zlist, edges)
        glob_edges = edges
        break
    end
end
# Out:
# 1回目の繰り返し: 6.136262
# 2回目の繰り返し: 1.355946
# 3回目の繰り返し: 0.726759
# 4回目の繰り返し: 0.402316
# 5回目の繰り返し: 0.223306
# 6回目の繰り返し: 0.124055
# 7回目の繰り返し: 0.069053
# 8回目の繰り返し: 0.038565
# 9回目の繰り返し: 0.021665
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 10回目の繰り返し: 0.012297
# 11回目の繰り返し: 0.007105

# %%
_, zlist_landmark = make_edges(hat_xs, zlist)
# Out:
# (Any[ObsEdge(11, 39, [1.181488561820693, 1.1774093095684983, 2.5975632326115616], [-0.9815371840593666, 1.3404844631891497, 9.596436984808218], [4.427758172741126, 0.31720215585292566], [2.669037708543687, -0.47510317987422784], [2.6854866545690923 3.0697758799659534 -15.91812066324258; 3.069775879965954 14.073915489101035 -63.77637799388914; -15.918120663242581 -63.77637799388914 291.00340374272395], [-2.6854866545690923 -3.0697758799659534 9.960779412442923; -3.069775879965954 -14.073915489101035 38.29587773634244; 15.918120663242581 63.77637799388914 -175.13985554591287], [-2.6854866545690923 -3.0697758799659534 15.91812066324258; -3.069775879965954 -14.073915489101035 63.77637799388914; 9.960779412442925 38.29587773634244 -175.13985554591287], [2.6854866545690923 3.0697758799659534 -9.960779412442923; 3.069775879965954 14.073915489101035 -38.29587773634244; -9.960779412442925 -38.29587773634244 105.4873699141581], [-1.1707386882096795, -1.7095090946492486, 8.541162461989751], [1.1707386882096795, 1.7095090946492486, -5.287987611015857]), ObsEdge(11, 58, [1.181488561820693, 1.1774093095684983, 2.5975632326115616], [1.4744968449468652, 0.059567393944372465, 14.574900597190766], [4.427758172741126, 0.31720215585292566], [5.317012965096577, 0.7744737609198799], [1.7043528015931906 2.0183447412324744 -10.404928716599372; 2.0183447412324744 7.487363174984115 -34.312791524324815; -10.404928716599372 -34.312791524324815 158.39772618607617], [-1.7043528015931906 -2.0183447412324744 13.229323781979328; -2.0183447412324744 -7.487363174984115 41.04446346436224; 10.404928716599372 34.312791524324815 -190.25283005454307], [-1.7043528015931906 -2.0183447412324744 10.404928716599372; -2.0183447412324744 -7.487363174984115 34.312791524324815; 13.229323781979328 41.04446346436224 -190.2528300545431], [1.7043528015931906 2.0183447412324744 -13.229323781979328; 2.0183447412324744 7.487363174984115 -41.04446346436224; -13.229323781979328 -41.04446346436224 229.03895612017476], [-1.1327791607981263, -2.603354097437783, 12.3597159145949], [1.1327791607981263, 2.603354097437783, -15.07540679400943]), ObsEdge(11, 59, [1.181488561820693, 1.1774093095684983, 2.5975632326115616], [1.1537784721684783, 0.5543058822368049, 14.849511140784548], [4.427758172741126, 0.31720215585292566], [5.051169656416052, 0.5300385797622542], [1.7296932461027712 2.0409962726638637 -10.527887780482438; 2.0409962726638637 8.11796733932652 -37.05598764943175; -10.527887780482438 -37.05598764943175 170.35524375106178], [-1.7296932461027712 -2.0409962726638637 12.576473031856171; -2.0409962726638637 -8.11796733932652 42.13893333482824; 10.527887780482438 37.05598764943175 -194.32467190696212], [-1.7296932461027712 -2.0409962726638637 10.527887780482438; -2.0409962726638637 -8.11796733932652 37.05598764943175; 12.576473031856171 42.13893333482824 -194.32467190696212], [1.7296932461027712 2.0409962726638637 -12.576473031856171; 2.0409962726638637 8.11796733932652 -42.13893333482824; -12.576473031856171 -42.13893333482824 221.96489019332813], [-0.8343210086761456, -0.9253059047374139, 4.8228564485144325], [0.8343210086761456, 0.9253059047374139, -5.783369631062467]), ObsEdge(11, 57, [1.181488561820693, 1.1774093095684983, 2.5975632326115616], [1.652938718927953, -0.5037792963659229, 14.312974289292125], [4.427758172741126, 0.31720215585292566], [5.281389130684098, 0.9111907249243695], [1.9763831770947826 2.2325358030872287 -11.59989503448361; 2.2325358030872287 6.707782324401915 -31.162694373411163; -11.59989503448361 -31.162694373411163 145.99701821825457], [-1.9763831770947826 -2.2325358030872287 15.29290853141328; -2.2325358030872287 -6.707782324401915 36.845153914917326; 11.59989503448361 31.162694373411163 -174.19038620026458], [-1.9763831770947826 -2.2325358030872287 11.59989503448361; -2.2325358030872287 -6.707782324401915 31.162694373411163; 15.29290853141328 36.845153914917326 -174.1903862002646], [1.9763831770947826 2.2325358030872287 -15.29290853141328; 2.232535803087 ...

# %%
mutable struct MapEdge
    x
    z
    m
    Omega
    xi
end

# %%
function MapEdge_(t, z, head_t, head_z, xs, sensor_noise_rate=[0.14, 0.05])
    self = MapEdge(ntuple(x->nothing, fieldcount(MapEdge))...)
    self.x = xs[t]
    self.z = z
    self.m = self.x[1:2] + [
        z[1]*cos(self.x[3] + z[2]),
        z[1]*sin(self.x[3] + z[2])]
    
    Q1 = Diagonal([(self.z[1]*sensor_noise_rate[1])^2, 
            sensor_noise_rate[2]^2])
    s1 = sin(self.x[3] + self.z[2])
    c1 = cos(self.x[3] + self.z[2])
    R = [-c1 self.z[1]*s1;
            -s1 -self.z[1]*c1]
    self.Omega = R * Q1 * R'
    self.xi = self.Omega * self.m
    return self
end
# Out:
# MapEdge_ (generic function with 2 methods)

# %%
function draw_landmarks(ms, ax)
    ax.scatter([m[1] for m in values(ms)], [m[2] for m in values(ms)], s=100, 
        marker="*", color="blue", zorder=100)
end
# Out:
# draw_landmarks (generic function with 1 method)

# %%
function draw(xs, zlist, edges, ms=[])
    ax = make_ax()
    draw_observations(xs, zlist, ax)
    draw_trajectory(xs, ax)
    draw_landmarks(ms, ax)
end
# Out:
# draw (generic function with 10 methods)

# %%
ms = []
for landmark_id in keys(zlist_landmark)
    edges = []
    head_z = zlist_landmark[landmark_id][1]
    for z in zlist_landmark[landmark_id]
        push!(edges, MapEdge_(z[1], z[2][2], head_z[1], head_z[2][2], hat_xs))
    end
    Omega = zeros(2,2)
    xi = zeros(2)
    for e in edges
        Omega += e.Omega
        xi += e.xi
    end
    push!(ms, inv(Omega)*xi)
end

# %%
draw(hat_xs, zlist, glob_edges, ms)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x7fa814ba19a0>
